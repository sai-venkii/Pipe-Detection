# %%
from ultralytics import YOLO

# %%
model = YOLO("D:\College\Sem 5\Package\ML\Circles\Mywork\yolo11n.pt")
# model = YOLO()

# %%
results = model.train(data="config.yaml", epochs=50)
# Out:
# New https://pypi.org/project/ultralytics/8.3.22 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.20  Python-3.11.3 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
pred_model=YOLO("D:\College\Sem 5\Package\ML\Circles\Mywork\\runs\detect\\train22\weights\\best.pt")

# %%
image_path = "D:\College\Sem 5\Package\ML\Circles\Mywork\data\\100.jpeg"  # Replace with the actual image path
results = model.predict(image_path, save=True,hide_labels=True, hide_conf=True,project="D:\College\Sem 5\Package\ML\Circles\Mywork\output")
# Out:
# WARNING  'hide_labels' is deprecated and will be removed in in the future. Use 'show_labels' instead.
# WARNING  'hide_conf' is deprecated and will be removed in in the future. Use 'show_conf' instead.
#
# image 1/1 D:\College\Sem 5\Package\ML\Circles\Mywork\data\100.jpeg: 480x640 1 skateboard, 93.7ms
# Speed: 2.0ms preprocess, 93.7ms inference, 180.1ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to D:\College\Sem 5\Package\ML\Circles\Mywork\output\predict

# %%
from IPython.display import Image,display
print("Number of Pipes = ", results[0].boxes.data.size(0))
img = results[0].save_dir +"\\" +results[0].path.split('\\')[-1]
img = img.split(".")[0]+".jpg"
display(Image(filename=img,width=400,height=400))
# Out:
# Number of Pipes =  1
