# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('./data/1.jpeg',0)
canny = cv2.Canny(img,1000,1000)

# %%
titles = ['image', canny]
images = [img, canny]

# %%
for i in range(len(images)):
    plt.subplot(1,len(images),i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()
